# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MohdRashids/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# ## My Lane
# I chose the Content Performance Prediction lane because it helps identify web pages that may lose search impressions in the future. Predicting these pages early allows website owners to improve their content and SEO before traffic declines. This problem has practical value and can help make better optimization decisions.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# ## Research Question
# Can we identify content pages that are likely to lose search impressions over the next 30 days?
#
# **Decision:** Decide which pages should be optimized first.
#
# **Action:** Update content, improve SEO, refresh outdated information, and monitor rankings.
#
# **Cost of a wrong call:** Time and effort may be spent on the wrong pages while important pages continue to lose traffic and visibility.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %% [markdown]
# ## Quick look at the data
#
# The starter dataset contains a large amount of search performance data, making it suitable for machine learning.
#
# Some observations:
# - The `fact_daily` table contains **78,835,655** rows.
# - The `dim_content` table contains **519,606** content items.
# - My feature-building step produced **111,247** content items with enough history for analysis.
#
# These numbers show that the dataset is large enough to study content performance and build predictive models.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Careful words
#
# This project can identify patterns in historical search performance and help prioritize which pages may need attention.
#
# It provides decision support, not certainty. The model cannot guarantee that a page will lose traffic or prove that a specific SEO change caused an improvement. Final decisions should always include human review.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
